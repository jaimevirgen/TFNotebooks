# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import seaborn as sns

sns.set(rc={"figure.figsize": (16, 16)})

filePath = '/Users/jaimevirgen/Code/Repos/TFNotebooks/Notebooks/ChartTemp/Data/20180620.csv'

df = pd.read_csv(filePath, parse_dates=['datetime'], usecols=['datetime', 'Temperature-Internal' ])

df.plot(x='datetime',  y='Temperature-Internal' , style='--' )

plt.savefig('/Users/jaimevirgen/Code/Repos/TFNotebooks/Notebooks/ChartTemp/Chart')

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import seaborn as sns

sns.set(rc={"figure.figsize": (16, 9)})

plt.figure()

f, axes = plt.subplots(2,1)

# f.suptitle('Readings for June 24 2018')

filePath = '/Users/jaimevirgen/Code/Repos/TFNotebooks/Notebooks/ChartTemp/Data/20180624.csv'

filePathDictionary = ['/Users/jaimevirgen/Code/Repos/TFNotebooks/Notebooks/ChartTemp/Data/20180620.csv',
                      '/Users/jaimevirgen/Code/Repos/TFNotebooks/Notebooks/ChartTemp/Data/20180621.csv',
                      '/Users/jaimevirgen/Code/Repos/TFNotebooks/Notebooks/ChartTemp/Data/20180622.csv',
                      '/Users/jaimevirgen/Code/Repos/TFNotebooks/Notebooks/ChartTemp/Data/20180623.csv',
                      '/Users/jaimevirgen/Code/Repos/TFNotebooks/Notebooks/ChartTemp/Data/20180624.csv',
                      '/Users/jaimevirgen/Code/Repos/TFNotebooks/Notebooks/ChartTemp/Data/20180625.csv']

frames = {}

for file in filePathDictionary:
    frames[file] = pd.read_csv(file, parse_dates=['datetime'], usecols=['datetime', 'Temperature-Internal','Humidity', 'Pressure'])


x = pd.to_datetime(frames[filePathDictionary[0]]['datetime'], format='%Y-%m-%d %H:%M:%S.%f')

y1 = frames[filePathDictionary[0]]['Temperature-Internal']

plt.rcParams['lines.linewidth'] = 0.5

p1 = frames[filePathDictionary[0]]['Temperature-Internal'].plot(ax=axes[0], alpha=0.1)
axes[0].set_ylabel('Temp')
axes[0].set_ylim([60, 95])

p2 = frames[filePathDictionary[1]]['Temperature-Internal'].plot(ax=axes[0], alpha=0.15)

p3 = frames[filePathDictionary[2]]['Temperature-Internal'].plot(ax=axes[0], alpha=0.35)

p4 = frames[filePathDictionary[3]]['Temperature-Internal'].plot(ax=axes[0], alpha=0.45)

p5 = frames[filePathDictionary[4]]['Temperature-Internal'].plot(ax=axes[0], alpha=0.75)

plt.rcParams['lines.linewidth'] = 2.0

p6 = frames[filePathDictionary[5]]['Temperature-Internal'].plot(ax=axes[0], alpha=1)

# 
# 

plt.rcParams['lines.linewidth'] = 0.5

p12 = frames[filePathDictionary[0]]['Humidity'].plot(ax=axes[1], alpha=0.1)
axes[0].set_ylabel('Humidity')
axes[0].set_ylim([60, 95])

p22 = frames[filePathDictionary[1]]['Humidity'].plot(ax=axes[1], alpha=0.2)

p32 = frames[filePathDictionary[2]]['Humidity'].plot(ax=axes[1], alpha=0.35)

p42 = frames[filePathDictionary[3]]['Humidity'].plot(ax=axes[1], alpha=0.5)

p52 = frames[filePathDictionary[4]]['Humidity'].plot(ax=axes[1], alpha=0.75)

plt.rcParams['lines.linewidth'] = 2.0

p62 = frames[filePathDictionary[5]]['Humidity'].plot(ax=axes[1], alpha=1)



plt.savefig('/Users/jaimevirgen/Code/Repos/TFNotebooks/Notebooks/ChartTemp/20180624')

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import seaborn as sns

sns.set(rc={"figure.figsize": (16, 9)})

sns.set_style("darkgrid")


filePath = '/Users/jaimevirgen/Code/Repos/TFNotebooks/Notebooks/ChartTemp/Data/20180625.csv'

parser = lambda date: pd.to_datetime(date)

# df = pd.read_csv(filePath, index_col='datetime', infer_datetime_format=True, usecols=['datetime', 'Temperature-Internal'])


df = pd.read_csv(filePath, index_col='datetime', parse_dates=[0], date_parser=parser, usecols=['datetime', 'Temperature-Internal'])
# df = pd.to_datetime(df['datetime'])


df.plot(y='Temperature-Internal', lw=1.5)
