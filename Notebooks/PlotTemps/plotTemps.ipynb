# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.dates import bytespdate2num

time, impressions = np.loadtxt("/Users/jaimevirgen/Code/Repos/TFNotebooks/Notebooks/PlotTemps/20180619.csv", unpack=True, delimiter=',', converters={0: bytespdate2num('%H:%M:%S.%f')})

plt.style.use('default')

plt.plot_date(x=time, y=impressions)
plt.show()
